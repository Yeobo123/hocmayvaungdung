# %%
import pandas as pd

# Tải dữ liệu từ file CSV
url = 'https://drive.google.com/uc?id=1Gn6YWHXRuPbTUXY5HFxM5C_tJHuZxCka'
data = pd.read_csv(url)

# Xem qua dữ liệu
print(data.head())
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# Tách dữ liệu thành tập huấn luyện và tập kiểm tra
X = data['Text']
y = data['Label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Chuyển đổi văn bản thành số
vectorizer = CountVectorizer()
X_train_counts = vectorizer.fit_transform(X_train)
X_test_counts = vectorizer.transform(X_test)

# Chuyển đổi nhãn thành số
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)


# Áp dụng Naive Bayes với phân phối Bernoulli
bernoulli_model = BernoulliNB()
bernoulli_model.fit(X_train_counts, y_train_encoded)
y_pred_bernoulli = bernoulli_model.predict(X_test_counts)

# Áp dụng Naive Bayes với phân phối Multinomial
multinomial_model = MultinomialNB()
multinomial_model.fit(X_train_counts, y_train_encoded)
y_pred_multinomial = multinomial_model.predict(X_test_counts)

# Dự đoán cho toàn bộ tập kiểm tra với mô hình BernoulliNB
y_pred_bernoulli_full = bernoulli_model.predict(X_test_counts)
y_pred_bernoulli_proba_full = bernoulli_model.predict_proba(X_test_counts)

# Dự đoán cho toàn bộ tập kiểm tra với mô hình MultinomialNB
y_pred_multinomial_full = multinomial_model.predict(X_test_counts)
y_pred_multinomial_proba_full = multinomial_model.predict_proba(X_test_counts)

# In kết quả dự đoán cho tập kiểm tra
print("Dự đoán với BernoulliNB cho toàn bộ tập kiểm tra:")
for text, true_label, pred, proba in zip(X_test, y_test, y_pred_bernoulli_full, y_pred_bernoulli_proba_full):
    true_label = true_label
    pred_label = label_encoder.inverse_transform([pred])[0]
    print(f"Văn bản: \"{text}\"")
    print(f"Nhãn thực tế: {true_label}")
    print(f"Dự đoán: {pred_label}")
    print(f"Xác suất dự đoán: {proba}")
    print()

print("Dự đoán với MultinomialNB cho toàn bộ tập kiểm tra:")
for text, true_label, pred, proba in zip(X_test, y_test, y_pred_multinomial_full, y_pred_multinomial_proba_full):
    true_label = true_label
    pred_label = label_encoder.inverse_transform([pred])[0]
    print(f"Văn bản: \"{text}\"")
    print(f"Nhãn thực tế: {true_label}")
    print(f"Dự đoán: {pred_label}")
    print(f"Xác suất dự đoán: {proba}")
    print()
# Out:
#                                                 Text     Label
# 0  The impact of educational reforms remains unce...  positive
# 1  Critics argue that recent improvements in the ...  negative
# 2  Innovative teaching methods have led to unexpe...  positive
# 3  Despite budget constraints, the school has man...  positive
# 4  The true effectiveness of online learning plat...  negative
# Dự đoán với BernoulliNB cho toàn bộ tập kiểm tra:
# Văn bản: "Educational policies fail to address the diverse needs of students from different backgrounds."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.75657415 0.24342585]
#
# Văn bản: "Educational initiatives often prioritize short-term gains over long-term sustainability."
# Nhãn thực tế: positive
# Dự đoán: negative
# Xác suất dự đoán: [0.5156164 0.4843836]
#
# Văn bản: "Educational policies should be responsive to the needs and aspirations of diverse communities."
# Nhãn thực tế: negative
# Dự đoán: positive
# Xác suất dự đoán: [0.27586361 0.72413639]
#
# Văn bản: "Higher education should prioritize critical thinking skills over rote memorization."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.09364817 0.90635183]
#
# Văn bản: "Parental involvement is crucial for student success and academic achievement."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.4503404 0.5496596]
#
# Văn bản: "The role of standardized testing in education remains a contentious issue."
# Nhãn thực tế: positive
# Dự đoán: negative
# Xác suất dự đoán: [0.97248703 0.02751297]
#
# Văn bản: "Privatization efforts in education prioritize profit over student well-being."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.98687746 0.01312254]
#
# Văn bản: "Online education offers flexibility but lacks the social interaction of traditional classrooms."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.84092215 0.15907785]
#
# Văn bản: "Despite budget constraints, the school has managed to maintain a high level of academic excellence."
# Nhãn thực tế: positive
# Dự đoán: negative
# Xác suất dự đoán: [0.67608342 0.32391658]
#
# Văn bản: "Education should empower students to become lifelong learners and critical thinkers."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.09831724 0.90168276]
#
# Văn bản: "Online learning platforms provide flexibility, but they lack the personal interaction of traditional classrooms."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.34257762 0.65742238]
#
# Văn bản: "Charter schools offer alternatives to traditional education, but their effectiveness is debated."
# Nhãn thực tế: positive
# Dự đoán: negative
# Xác suất dự đoán: [0.68562617 0.31437383]
#
# Văn bản: "Educators should receive more support and recognition for their crucial role in society."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.2337055 0.7662945]
#
# Văn bản: "School curricula should focus more on practical skills and less on theoretical knowledge."
# Nhãn thực tế: positive
# Dự đoán: negative
# Xác suất dự đoán: [0.68828022 0.31171978]
#
# Văn bản: "Educational standards should be flexible to accommodate diverse learning styles."
# Nhãn thực tế: negative
# Dự đoán: positive
# Xác suất dự đoán: [0.04355284 0.95644716]
#
# Văn bản: "The true effectiveness of online learning platforms is still a matter of debate among educators."
# Nhãn thực tế: negative
# Dự đoán: positive
# Xác suất dự đoán: [0.36048352 0.63951648]
#
# Văn bản: "Underfunded schools struggle to provide adequate resources and support for students."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.84926403 0.15073597]
#
# Văn bản: "Budget cuts in education result in larger class sizes and fewer resources for students."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.93106379 0.06893621]
#
# Văn bản: "Project-based learning encourages collaboration and problem-solving skills."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.09191986 0.90808014]
#
# Văn bản: "Standardized tests fail to capture the full range of students' abilities and potential."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.95332412 0.04667588]
#
# Văn bản: "Educational inequities persist despite efforts to bridge the gap."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.67424813 0.32575187]
#
# Dự đoán với MultinomialNB cho toàn bộ tập kiểm tra:
# Văn bản: "Educational policies fail to address the diverse needs of students from different backgrounds."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.72823212 0.27176788]
#
# Văn bản: "Educational initiatives often prioritize short-term gains over long-term sustainability."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.47302747 0.52697253]
#
# Văn bản: "Educational policies should be responsive to the needs and aspirations of diverse communities."
# Nhãn thực tế: negative
# Dự đoán: positive
# Xác suất dự đoán: [0.26631063 0.73368937]
#
# Văn bản: "Higher education should prioritize critical thinking skills over rote memorization."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.1099373 0.8900627]
#
# Văn bản: "Parental involvement is crucial for student success and academic achievement."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.36070615 0.63929385]
#
# Văn bản: "The role of standardized testing in education remains a contentious issue."
# Nhãn thực tế: positive
# Dự đoán: negative
# Xác suất dự đoán: [0.94665327 0.05334673]
#
# Văn bản: "Privatization efforts in education prioritize profit over student well-being."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.97532402 0.02467598]
#
# Văn bản: "Online education offers flexibility but lacks the social interaction of traditional classrooms."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.82554319 0.17445681]
#
# Văn bản: "Despite budget constraints, the school has managed to maintain a high level of academic excellence."
# Nhãn thực tế: positive
# Dự đoán: negative
# Xác suất dự đoán: [0.66349218 0.33650782]
#
# Văn bản: "Education should empower students to become lifelong learners and critical thinkers."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.09001515 0.90998485]
#
# Văn bản: "Online learning platforms provide flexibility, but they lack the personal interaction of traditional classrooms."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.3716658 0.6283342]
#
# Văn bản: "Charter schools offer alternatives to traditional education, but their effectiveness is debated."
# Nhãn thực tế: positive
# Dự đoán: negative
# Xác suất dự đoán: [0.66349218 0.33650782]
#
# Văn bản: "Educators should receive more support and recognition for their crucial role in society."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.18239445 0.81760555]
#
# Văn bản: "School curricula should focus more on practical skills and less on theoretical knowledge."
# Nhãn thực tế: positive
# Dự đoán: negative
# Xác suất dự đoán: [0.81516196 0.18483804]
#
# Văn bản: "Educational standards should be flexible to accommodate diverse learning styles."
# Nhãn thực tế: negative
# Dự đoán: positive
# Xác suất dự đoán: [0.06421383 0.93578617]
#
# Văn bản: "The true effectiveness of online learning platforms is still a matter of debate among educators."
# Nhãn thực tế: negative
# Dự đoán: positive
# Xác suất dự đoán: [0.43032423 0.56967577]
#
# Văn bản: "Underfunded schools struggle to provide adequate resources and support for students."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.7677089 0.2322911]
#
# Văn bản: "Budget cuts in education result in larger class sizes and fewer resources for students."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.94694029 0.05305971]
#
# Văn bản: "Project-based learning encourages collaboration and problem-solving skills."
# Nhãn thực tế: positive
# Dự đoán: positive
# Xác suất dự đoán: [0.07482262 0.92517738]
#
# Văn bản: "Standardized tests fail to capture the full range of students' abilities and potential."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.90818899 0.09181101]
#
# Văn bản: "Educational inequities persist despite efforts to bridge the gap."
# Nhãn thực tế: negative
# Dự đoán: negative
# Xác suất dự đoán: [0.67305367 0.32694633]
